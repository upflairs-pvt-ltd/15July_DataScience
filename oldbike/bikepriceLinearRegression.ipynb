# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
df = pd.read_csv('Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.duplicated().sum()
# Out:
# 25324

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
##  missing value checking  
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
dt = {"First Owner":1,"Second Owner":2,"Third Owner":3,"Fourth Owner Or More":4} 
dt
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner Or More': 4}

# %%
# for ownership in df['owner']:
#     print(dt[ownership])

df['owner'] = df['owner'].map(dt)

# %%
df['brand'].nunique()
# Out:
# 23

# %%
brand_ls = list(df['brand'].value_counts().head(16).keys())
brand_ls
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW']

# %%
df2 = df[df['brand'].isin(brand_ls)]
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power          brand
# 0      1  3.0  110.0            TVS
# 1      1  4.0  350.0  Royal Enfield
# 2      1  8.0  675.0        Triumph
# 3      1  4.0  180.0            TVS
# 4      1  3.0  150.0         Yamaha

# %%
data_dic = {}
i = 1
for brand in list(df2['brand'].value_counts().keys()): 
    data_dic[brand] = i 
    i = i + 1
data_dic
# Out:
# {'Bajaj': 1,
#  'Royal Enfield': 2,
#  'Hero': 3,
#  'Honda': 4,
#  'Yamaha': 5,
#  'TVS': 6,
#  'KTM': 7,
#  'Suzuki': 8,
#  'Harley-Davidson': 9,
#  'Kawasaki': 10,
#  'Hyosung': 11,
#  'Mahindra': 12,
#  'Benelli': 13,
#  'Triumph': 14,
#  'Ducati': 15,
#  'BMW': 16}

# %%
brand_dict  = {brand:i for i , brand in enumerate(list(df2['brand'].value_counts().keys()),start=1)}
print(brand_dict)
df2['brand'] = df2['brand'].map(brand_dict)  
# single time
# Out:
# {'Bajaj': 1, 'Royal Enfield': 2, 'Hero': 3, 'Honda': 4, 'Yamaha': 5, 'TVS': 6, 'KTM': 7, 'Suzuki': 8, 'Harley-Davidson': 9, 'Kawasaki': 10, 'Hyosung': 11, 'Mahindra': 12, 'Benelli': 13, 'Triumph': 14, 'Ducati': 15, 'BMW': 16}
# C:\Users\Ranjit\AppData\Local\Temp\ipykernel_8064\3200332288.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['brand'] = df2['brand'].map(brand_dict)

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power          brand
# 0      1  3.0  110.0            TVS
# 1      1  4.0  350.0  Royal Enfield
# 2      1  8.0  675.0        Triumph
# 3      1  4.0  180.0            TVS
# 4      1  3.0  150.0         Yamaha

# %%
data_dic = {}
for i,item in enumerate(brand_ls,start=1): 
    data_dic[item]  = i  

data_dic
# Out:
# {'Bajaj': 1,
#  'Royal Enfield': 2,
#  'Hero': 3,
#  'Honda': 4,
#  'Yamaha': 5,
#  'TVS': 6,
#  'KTM': 7,
#  'Suzuki': 8,
#  'Harley-Davidson': 9,
#  'Kawasaki': 10,
#  'Hyosung': 11,
#  'Mahindra': 12,
#  'Benelli': 13,
#  'Triumph': 14,
#  'Ducati': 15,
#  'BMW': 16}

# %%
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power  brand
# 0      1  3.0  110.0      6
# 1      1  4.0  350.0      2
# 2      1  8.0  675.0     14
# 3      1  4.0  180.0      6
# 4      1  3.0  150.0      5

# %%
df2.drop(['bike_name','city'],axis=1,inplace=True)
# Out:
# C:\Users\Ranjit\AppData\Local\Temp\ipykernel_8064\1642961446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(['bike_name','city'],axis=1,inplace=True)

# %%
df2.head(2)
# Out:
#       price  kms_driven  owner  age  power  brand
# 0   35000.0     17654.0      1  3.0  110.0      6
# 1  119900.0     11000.0      1  4.0  350.0      2

# %%
x = df2.drop('price',axis=1)
y = df2[['price']]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7307 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split 
# scikit-learn

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)  # 80% training size

# %%
from sklearn.linear_model import LinearRegression   # algorithm import

# %%
lnr = LinearRegression()

# %%
lnr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train.shape
# Out:
# (5845, 5)

# %%
x_train.isnull().sum()
# Out:
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
x_train   # valueerror
# Out:
#       kms_driven  owner   age  power  brand
# 9255      1050.0      1   3.0  125.0      7
# 1749      5000.0      1   2.0  350.0      2
# 720       7000.0      1   6.0  200.0      1
# 2987     10181.0      1   4.0  100.0      1
# 1953      5100.0      1   7.0  250.0     11
# ...          ...    ...   ...    ...    ...
# 7627     11000.0      1   3.0  220.0      1
# 9142     40000.0      1   8.0  125.0      1
# 5095     36888.0      1  13.0  135.0      1
# 5351     30000.0      1   9.0  125.0      3
# 3036     36000.0      1   6.0  180.0      6
#
# [5845 rows x 5 columns]

# %%
lnr.score(x_train,y_train)*100    # 75% scored
# Out:
# 73.15469351569655

# %%
# unseen data or test data or validation data (x_test,y_test)
lnr.score(x_test,y_test)* 100
# Out:
# 76.90068723809598

# %%
## prediction 
prediction = lnr.predict(x_test)

# %%
y_test['prediction'] = prediction

# %%
y_test.head(40)
# Out:
#          price     prediction
# 7275   30000.0   17257.096500
# 1450  180000.0  171456.981779
# 1021  699000.0  547958.391882
# 3278   67000.0   17581.758199
# 1394   52000.0   22240.487096
# 8259   25500.0    5675.819714
# 6022  161100.0  145541.780890
# 736    31500.0   12396.334611
# 6097   95000.0  215111.346039
# 67    106000.0  133280.375164
# 6349   34000.0   -1786.563185
# 2894   70000.0   56051.522013
# 1964   83000.0  110632.482470
# 5982   47000.0   55575.624206
# 3264   12000.0    5330.699491
# 5697  108000.0  209506.580435
# 3282  115000.0  128536.758342
# 1858   32000.0    2966.694462
# 7200   16000.0  -14385.141313
# 5559   55000.0   50562.324561
# 3158   45000.0   63014.262305
# 3645   23000.0   11630.090793
# 6187  115000.0  127454.556411
# 4795   44600.0   65946.471382
# 4081   71000.0  105106.297840
# 6313   20000.0   19112.550003
# 6300   18000.0   36776.763706
# 808    18500.0   -5783.298400
# 4552   17500.0     369.040422
# 4782   10000.0  -16312.991349
# 6988   65000.0  110497.693964
# 6104   59000.0  108513.831816
# 1501   45000.0   22660.952350
# 4170   10005.0   32171.553823
# 573   110000.0  208053.859880
# 8657   41000.0   13785.735394
# 571   150000.0  219942.783870
# 4885   39500.0   25084.223222
# 6267   24000.0   31125.240112
# 439    21000.0   62876.438448

# %%
import os  , joblib

# %%
os.makedirs('models',exist_ok=True)    # models

# %%
lnr     # algorithm and model
# Out:
# LinearRegression()

# %%
joblib.dump(lnr,"./models/linear_model.lb")
# Out:
# ['./models/linear_model.lb']

# %%
salary
# Out:
# 600000
