# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
df = pd.read_csv('Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.duplicated().sum()
# Out:
# 25324

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
##  missing value checking  
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
dt = {"First Owner":1,"Second Owner":2,"Third Owner":3,"Fourth Owner Or More":4} 
dt
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner Or More': 4}

# %%
# for ownership in df['owner']:
#     print(dt[ownership])

df['owner'] = df['owner'].map(dt)

# %%
df['brand'].nunique()
# Out:
# 23

# %%
brand_ls = list(df['brand'].value_counts().head(16).keys())
brand_ls
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW']

# %%
df2 = df[df['brand'].isin(brand_ls)]
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power          brand
# 0      1  3.0  110.0            TVS
# 1      1  4.0  350.0  Royal Enfield
# 2      1  8.0  675.0        Triumph
# 3      1  4.0  180.0            TVS
# 4      1  3.0  150.0         Yamaha

# %%
data_dic = {}
i = 1
for brand in list(df2['brand'].value_counts().keys()): 
    data_dic[brand] = i 
    i = i + 1
data_dic
# Out:
# {'Bajaj': 1,
#  'Royal Enfield': 2,
#  'Hero': 3,
#  'Honda': 4,
#  'Yamaha': 5,
#  'TVS': 6,
#  'KTM': 7,
#  'Suzuki': 8,
#  'Harley-Davidson': 9,
#  'Kawasaki': 10,
#  'Hyosung': 11,
#  'Mahindra': 12,
#  'Benelli': 13,
#  'Triumph': 14,
#  'Ducati': 15,
#  'BMW': 16}

# %%
brand_dict  = {brand:i for i , brand in enumerate(list(df2['brand'].value_counts().keys()),start=1)}
print(brand_dict)
df2['brand'] = df2['brand'].map(brand_dict)  
# single time
# Out:
# {'Bajaj': 1, 'Royal Enfield': 2, 'Hero': 3, 'Honda': 4, 'Yamaha': 5, 'TVS': 6, 'KTM': 7, 'Suzuki': 8, 'Harley-Davidson': 9, 'Kawasaki': 10, 'Hyosung': 11, 'Mahindra': 12, 'Benelli': 13, 'Triumph': 14, 'Ducati': 15, 'BMW': 16}
# C:\Users\Ranjit\AppData\Local\Temp\ipykernel_12740\3200332288.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['brand'] = df2['brand'].map(brand_dict)

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power  brand
# 0      1  3.0  110.0    6.0
# 1      1  4.0  350.0    2.0
# 2      1  8.0  675.0   14.0
# 3      1  4.0  180.0    6.0
# 4      1  3.0  150.0    5.0

# %%
data_dic = {}
for i,item in enumerate(brand_ls,start=1): 
    data_dic[item]  = i  

data_dic
# Out:
# {'Bajaj': 1,
#  'Royal Enfield': 2,
#  'Hero': 3,
#  'Honda': 4,
#  'Yamaha': 5,
#  'TVS': 6,
#  'KTM': 7,
#  'Suzuki': 8,
#  'Harley-Davidson': 9,
#  'Kawasaki': 10,
#  'Hyosung': 11,
#  'Mahindra': 12,
#  'Benelli': 13,
#  'Triumph': 14,
#  'Ducati': 15,
#  'BMW': 16}

# %%
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power  brand
# 0      1  3.0  110.0      6
# 1      1  4.0  350.0      2
# 2      1  8.0  675.0     14
# 3      1  4.0  180.0      6
# 4      1  3.0  150.0      5

# %%
df2.drop(['bike_name','city'],axis=1,inplace=True)
# Out:
# C:\Users\Ranjit\AppData\Local\Temp\ipykernel_12740\1642961446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(['bike_name','city'],axis=1,inplace=True)

# %%
df2.head(2)
# Out:
#       price  kms_driven  owner  age  power  brand
# 0   35000.0     17654.0      1  3.0  110.0      6
# 1  119900.0     11000.0      1  4.0  350.0      2

# %%
x = df2.drop('price',axis=1)
y = df2[['price']]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7307 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split 
# scikit-learn

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)  # 80% training size

# %%
from sklearn.linear_model import LinearRegression   # algorithm import

# %%
lnr = LinearRegression()

# %%
lnr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train.shape
# Out:
# (5845, 5)

# %%
x_train.isnull().sum()
# Out:
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
x_train   # valueerror
# Out:
#       kms_driven  owner  age  power  brand
# 7093      1600.0      1  4.0  400.0      1
# 802      25000.0      1  7.0  200.0      7
# 4601     14536.0      1  7.0  125.0      1
# 9157     17870.0      1  7.0  110.0      6
# 3012     34500.0      2  7.0  150.0      5
# ...          ...    ...  ...    ...    ...
# 2747     17500.0      2  9.0  350.0      2
# 4271     14000.0      1  3.0  150.0      5
# 1809     12000.0      1  5.0  100.0      1
# 4046     18661.0      1  4.0  100.0      3
# 442      20000.0      1  5.0  350.0      2
#
# [5845 rows x 5 columns]

# %%
lnr.score(x_train,y_train)*100    # 75% scored
# Out:
# 75.19348334772553

# %%
# unseen data or test data or validation data (x_test,y_test)
lnr.score(x_test,y_test)* 100
# Out:
# 70.51029506934317

# %%
## prediction 
prediction = lnr.predict(x_test)

# %%
y_test['prediction'] = prediction

# %%
y_test.head(40)
# Out:
#          price     prediction
# 1079   47000.0   82699.706269
# 1705   88000.0  119038.261010
# 9151   21000.0   -9782.050239
# 8128   28000.0   25510.986172
# 4577   21000.0   -2979.180129
# 8791   21305.0   24002.843949
# 801   110000.0   57638.481036
# 4628   16000.0   24663.656943
# 8813  130000.0  132664.498428
# 5127   25000.0    9285.122737
# 3342   39000.0   48556.168092
# 7283   75000.0  123282.381940
# 479   150000.0  145637.928365
# 6979   24000.0    5931.573784
# 609   140000.0  185686.809901
# 8409  120000.0  140227.801201
# 3616  117000.0  142059.113656
# 8146   75000.0   49648.313099
# 345    20000.0   -7049.106001
# 2757   70700.0   46783.010440
# 8369  700000.0  497103.245920
# 2807   45000.0   49404.296804
# 2926   95000.0  136490.609614
# 807   115000.0  132876.084223
# 8334  100000.0   49010.175812
# 5903  114300.0   73159.365747
# 8418  105000.0  131561.326791
# 5835   36000.0   19635.100613
# 4335   26000.0   11247.067640
# 5199   32000.0   19902.930732
# 6565   19326.0   17012.634596
# 7815  123000.0  122340.811340
# 3781   13000.0   21903.335087
# 2561   47000.0   20271.375700
# 5064   26000.0   12347.821285
# 2849   60000.0   53331.290668
# 2448   73500.0  121407.571103
# 6992   80000.0   34845.062455
# 4510  150000.0  143014.374416
# 3034  130000.0  139390.921354
